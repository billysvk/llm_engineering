# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import requests
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
# set up environment

# %%
# here is the question; type over this to ask something new



question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

messages = [{"role": "user", "content": question }]

response = openai.chat.completions.create(model=MODEL_LLAMA, messages = messages)
print(response.choices[0].message.content)
# Out:
# This line of code is written in Python and uses a concept called "yield from" or "generator expression".
#
# Here's a breakdown of what it does:
#
# - `{...for book in books...}.get("author")`: This part is a generator expression. It creates an iterator (not a list) that yields each author name found in the dictionaries.
#
#   - `(...)`. The inner parentheses indicate the start of a generator expression.
#
#   - `{book.get("author")} ...`: Inside these, for each book (item of iteration), it gets (retrieves or fetches if present) the "author" value (`book.get("author)")`) from the dictionary. This also yields an author name into the generator expression.
#
# - `yield from {...}`: After the inner generator expression, `yield from` is used to delegate control of a function's execution (or a part thereof) to another generator (expression). It means "run this other generator next".
#
# - So, put it all together: It yields an author name for each book in `books`, but only if `book.get("author")` exists. The `yield from` keyword allows the iteration of multiple iterable things at once.
#
# Here's an example using real dictionaries (note that actual data would depend on what kind of data "books" and `"author"` represent):
#
# ```python
# books = [
#     {"title": "Book1", "author": "Author1"},
#     {"title": "Book2"},
#     {"title": "Book3", "author": "Author2"}
# ]
#
# for author in yield from ({book.get("author") for book in books if book.get("author")}):
#     print(f"The Author is {author}")
# ```
#
# In this example, since dictionaries like `"Book2"` do not have a key that can be accessed via `book("author")`, they are ignored (or considered "none" or the default value from those dictionaries), and each "Author1" and "Author2" would get printed accordingly.

# %%
# Get gpt-4o-mini to answer, with streaming

# %%
# Get Llama 3.2 to answer
